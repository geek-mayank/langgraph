# %%
from langgraph.graph import StateGraph, START,END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv
load_dotenv()
model = ChatGroq(model="openai/gpt-oss-120b")

# %%
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
def create_outline(state:BlogState)->BlogState:
    title = state['title']
    prompt = f'Generate an detailed outline for a blog on topic - {title}'
    outline = model.invoke(prompt).content
    state['outline'] = outline
    return state

# %%
def create_blog(state:BlogState)->BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the following \n {outline}'
    content = model.invoke(prompt).content

    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)
workflow = graph.compile()

# %%
initial_state = {'title':'Footbal'}
final_state = workflow.invoke(initial_state)
print(final_state['outline'])
# Out:
# **Title:** *The Beautiful Game: A Comprehensive Guide to Everything Football*
#
# ---
#
# ## 1. Introduction
#    - **Hook:** A vivid anecdote or striking statistic (e.g., “Over 4 billion people watch football each year”)
#    - **Why Football Matters:** Cultural impact, global reach, community building, economic significance.
#    - **What Readers Will Get:** A roadmap of the sport’s history, rules, tactics, culture, and how to get involved.
#
# ---
#
# ## 2. The Origins & Evolution of Football
# ### 2.1 Ancient Precursors
#    - Cuju (China), Kemari (Japan), Harpastum (Rome) – brief descriptions.
# ### 2.2 Codifying the Modern Game
#    - The 1863 formation of The Football Association (FA) in England.
#    - The split between association football and rugby.
# ### 2.3 Global Spread
#    - British expatriates, colonial influence, and early international matches.
# ### 2.4 Milestones in the 20th‑21st Century
#    - First World Cup (1930), introduction of the off‑side rule, TV broadcasting boom, VAR, and the rise of women's football.
#
# ---
#
# ## 3. The Fundamentals: Rules & Gameplay
# ### 3.1 The Laws of the Game (Overview)
#    - 17 Laws – quick bullet‑point summary.
# ### 3.2 The Pitch & Equipment
#    - Dimensions, markings, ball specifications, player gear.
# ### 3.3 Player Positions & Roles
#    - Goalkeeper, defenders (center‑back, full‑back), midfielders (defensive, box‑to‑box, attacking), forwards (winger, striker).
# ### 3.4 Match Structure
#    - Halves, stoppage time, extra time, penalty shoot‑outs.
# ### 3.5 Refereeing & Technology
#    - Assistant referees, VAR, goal‑line tech, recent rule changes (handball interpretation, sin‑bin trials).
#
# ---
#
# ## 4. Tactical Landscape
# ### 4.1 Formations Through the Ages
#    - 2‑3‑5 “Pyramid”, WM, 4‑4‑2, 4‑3‑3, 3‑5‑2, 4‑2‑3‑1, 3‑4‑3, false‑9, etc.
# ### 4.2 Core Concepts
#    - Possession vs. counter‑attack, pressing, zonal vs. man‑to‑man marking, high line, low block.
# ### 4.3 Set‑Piece Strategies
#    - Corner routines, free‑kick layouts, penalty takers psychology.
# ### 4.4 Data & Analytics
#    - Expected Goals (xG), heat maps, player tracking, how clubs use analytics for recruitment and in‑game decisions.
#
# ---
#
# ## 5. The Business of Football
# ### 5.1 Club Ownership Models
#    - Publicly listed clubs, private investors, fan‑owned (e.g., Barcelona, Bayern), sovereign wealth funds.
# ### 5.2 Revenue Streams
#    - Broadcast rights, match‑day income, sponsorship, merchandising, digital content.
# ### 5.3 Transfer Market Mechanics
#    - Transfer windows, player contracts, release clauses, loan system, Financial Fair Play (FFP).
# ### 5.4 Emerging Markets & Globalization
#    - MLS, Chinese Super League, Middle East investments, e‑sports tie‑ins.
#
# ---
#
# ## 6. The Cultural Phenomenon
# ### 6.1 Fan Identity & Community
#    - Ultras, supporter clubs, chants, match‑day rituals.
# ### 6.2 Football & Politics
#    - Nationalism, diplomatic “football diplomacy”, social movements (e.g., Black Lives Matter, LGBTQ+ inclusion).
# ### 6.3 Media & Storytelling
#    - Classic documentaries (e.g., *The Two Escobars*), podcasts, influencer culture, TikTok highlights.
# ### 6.4 Iconic Rivalries
#    - El Clásico, Manchester Derby, Superclásico, Old Firm, Der Klassiker – why they matter.
#
# ---
#
# ## 7. Women’s Football – A Rising Force
# ### 7.1 Historical Overview
#    - Early bans, resurgence in the 1970s, first Women’s World Cup (1991).
# ### 7.2 Current Landscape
#    - Top leagues (FA WSL, NWSL, Division 1 Féminine), star players, prize money growth.
# ### 7.3 Challenges & Opportunities
#    - Pay equity, media coverage, grassroots development, sponsorship.
#
# ---
#
# ## 8. Grassroots & How to Get Involved
# ### 8.1 Playing the Game
#    - Finding local clubs, age‑group pathways, training drills for beginners.
# ### 8.2 Coaching & Volunteering
#    - Certification routes (FA Level 1, UEFA B, etc.), volunteer roles at community clubs.
# ### 8.3 Spectating & Fan Experience
#    - Buying tickets, stadium etiquette, traveling for away games, virtual fan communities.
# ### 8.4 Fantasy Leagues & Gaming
#    - Overview of popular fantasy platforms, e‑sports titles (FIFA, eFootball), their impact on fan engagement.
#
# ---
#
# ## 9. The Future of Football
# ### 9.1 Technological Innovations
#    - AI‑driven tactics, wearables, VR/AR fan experiences, blockchain ticketing.
# ### 9.2 Sustainability & Social Responsibility
#    - Green stadium initiatives, carbon‑neutral tournaments, community outreach programs.
# ### 9.3 Potential Rule Changes & Experiments
#    - Sin‑bins, 5‑minute “quick‑restart” rule, expanded VAR usage, possible “shoot‑out” tie‑breakers.
# ### 9.4 Global Growth Projections
#    - Emerging talent hotbeds (Africa, South‑Asia), expansion of major tournaments, women's game trajectory.
#
# ---
#
# ## 10. Conclusion
#    - Recap of football’s multifaceted nature—sport, business, culture, and community.
#    - Call‑to‑action: Invite readers to share their favorite football memory, join a local club, or follow the blog for deeper dives into specific topics.
#
# ---
#
# ## 11. Bonus Resources (Optional Sidebar)
#    - **Reading List:** Classic books (e.g., *Inverting the Pyramid* by Jonathan Wilson).
#    - **Podcasts & YouTube Channels:** Recommended shows for tactics, history, and fan culture.
#    - **Glossary:** Quick reference of common football terms.
#    - **Infographics:** Printable pitch layout, formation cheat‑sheet, transfer market timeline.
#
# ---
#
# ### Formatting Tips for the Blog Post
# | Element | Suggested Style |
# |---------|-----------------|
# | **Headings** | H1 for title, H2 for main sections, H3 for sub‑sections. |
# | **Images** | Action shots, historic photos, tactical diagrams, stadium aerials. |
# | **Sidebars** | Use for “Did you know?” facts, player profiles, quick stats. |
# | **Calls‑to‑Action** | End of sections: “Comment your favorite formation!” or “Vote for the best rivalry.” |
# | **SEO Keywords** | football history, football rules, soccer tactics, women's football, football business, how to play football, football fan culture. |
# | **Internal Links** | Link to related posts (e.g., “Understanding VAR,” “Top 10 Soccer Drills for Beginners”). |
# | **External Links** | Official FA/UEFA pages, reputable stats sites (Opta, FBref), academic papers on sports economics. |
#
# ---
#
# ### Quick Draft Timeline (If Publishing a Series)
# | Week | Post Title | Focus |
# |------|------------|-------|
# | 1 | *From Cuju to the World Cup: The Epic Journey of Football* | History |
# | 2 | *The 17 Laws You Need to Know (And Why They Matter)* | Rules |
# | 3 | *Decoding the Modern 4‑3‑3: Tactical Breakdown* | Tactics |
# | 4 | *Moneyball on the Pitch: How Data Is Changing Football* | Analytics |
# | 5 | *Inside the Business: How Clubs Make Their Money* | Business |
# | 6 | *Why Rivalries Fuel the Game’s Passion* | Culture |
# | 7 | *Women’s Football: The Rise of the Game’s New Stars* | Women’s football |
# | 8 | *Your First Steps: Joining a Team & Getting the Most Out of Match‑Day* | Grassroots |
# | 9 | *Future Forecast: Tech, Sustainability, and the Next 50 Years* | Future |
# | 10| *Wrap‑Up & Community Spotlight* | Recap + Reader engagement |
#
# ---
#
# **End of Outline** – Ready for you to flesh out each section into a compelling, SEO‑friendly blog series that caters to newcomers, casual fans, and seasoned aficionados alike. Happy writing!

# %%
print(final_state['content'])
# Out:
# # **The Beautiful Game: A Comprehensive Guide to Everything Football**
#
# *By [Your Name] – Football Enthusiast, Writer & Analyst*
# *Published: August 12 2026*
#
# ---
#
# ## 1. Introduction
#
# ### Hook – A World‑Wide Phenomenon
#
# > **“Over 4 billion people tune in to watch football each year, and more than 265 million play the sport at least once a week.”**
#
# Those numbers aren’t just statistics; they’re a testament to why football is truly *the* beautiful game. From a dusty village pitch in Lagos to the gleaming turf of Wembley, the sport unites strangers, sparks rivalries, and fuels economies worth billions.
#
# ### Why Football Matters
#
# - **Cultural Impact:** National anthems echo in stadiums, club colours become family heirlooms, and a single goal can lift a nation’s spirit.
# - **Global Reach:** Football is spoken in every language. It bridges continents, with the FIFA World Cup the most‑watched single‑event broadcast in history.
# - **Community Building:** Local clubs act as social hubs, offering mentorship, health benefits, and a sense of belonging.
# - **Economic Significance:** In 2025, the global football industry generated **US$ 1.8 trillion** in revenue—from broadcasting rights to merchandise.
#
# ### What You’ll Get From This Guide
#
# - A concise **history** from ancient ball games to modern super‑clubs.
# - An easy‑to‑digest **rules** primer and a look at the technology shaping officiating.
# - A deep‑dive into **tactics**, data analytics, and formation evolution.
# - Insight into the **business side** – ownership models, revenue streams, and the transfer market.
# - Exploration of **culture**, rivalries, and the growing influence of **women’s football**.
# - Practical steps for **getting involved** at grassroots level, plus a look at the **future** of the sport.
#
# Ready to lace up your metaphorical boots? Let’s kick off.
#
# ---
#
# ## 2. The Origins & Evolution of Football
#
# ### 2.1 Ancient Precursors
#
# | Ancient Game | Region | Core Features | Legacy |
# |--------------|--------|---------------|--------|
# | **Cuju** | China (Han dynasty, 2nd century BC) | Leather ball kicked through a small net; military training exercise. | Recognised by FIFA as the earliest documented form of “football”. |
# | **Kemari** | Japan (Heian period, 7th century) | Non‑competitive, players keep a ball aloft using feet only. | Still played ceremonially at Shinto shrines today. |
# | **Harpastum** | Roman Empire (1st century AD) | Small, hard ball; high‑contact, with a “goal line” marked on the ground. | Influenced medieval European folk games. |
#
# These early ball‑games shared a simple premise: **use the feet to control a ball**. Over centuries, they evolved, merged, and travelled across continents, laying the groundwork for the sport we know today.
#
# ### 2.2 Codifying the Modern Game
#
# - **1863 – The Birth of The Football Association (FA):**
#   Representatives from 12 London clubs met at the Freemasons’ Tavern and drafted the first **Laws of the Game**. The FA’s rules distinguished “association football” (soccer) from rugby, which retained handling.
#
# - **The Split:**
#   The 1871 formation of the Rugby Football Union cemented the divide. From then on, “football” generally meant the foot‑only version, especially outside the British Isles.
#
# ### 2.3 Global Spread
#
# 1. **British Expatriates:** Sailors, engineers, and merchants introduced the game to ports in South America, Africa, and Asia.
# 2. **Colonial Influence:** Schools in India, South Africa, and the Caribbean adopted the FA rules, producing the first native clubs.
# 3. **Early International Matches:**
#    - 1872 – Scotland vs. England (the first official international).
#    - 1904 – Formation of FIFA in Paris, uniting 7 national associations.
#
# ### 2.4 Milestones in the 20th‑21st Century
#
# | Year | Milestone | Why It Matters |
# |------|-----------|----------------|
# | **1930** | First FIFA World Cup (Uruguay) | Set the template for a global tournament. |
# | **1958** | Introduction of the **off‑side rule** (two‑player requirement) | Shaped modern attacking play. |
# | **1970** | First live colour TV broadcast of a World Cup final (Mexico) | Catapulted football into living rooms worldwide. |
# | **1992** | Creation of the **UEFA Champions League** (rebranded from European Cup) | Turned club football into a global spectacle. |
# | **2012** | Launch of **VAR** (Video Assistant Referee) in a trial phase | Began a tech‑driven officiating era. |
# | **2019** | Record‑breaking **Women's World Cup** (France) – 1.12 billion viewers | Signalled the commercial rise of women’s football. |
# | **2022** | **Goal‑line technology** becomes mandatory in top leagues | Eliminated “ghost goals” and increased fairness. |
# | **2025** | **AI‑driven tactical analysis** adopted by 70 % of elite clubs | Demonstrates data’s central role in modern football. |
#
# ---
#
# ## 3. The Fundamentals: Rules & Gameplay
#
# ### 3.1 The Laws of the Game (Overview)
#
# 1. **The Field of Play** – dimensions, markings, and surface.
# 2. **The Ball** – size 5, circumference 68‑70 cm, pressure 0.6‑1.1 bar.
# 3. **The Number of Players** – 11 per side; up to 3 substitutes (5 in some competitions).
# 4. **The Players’ Equipment** – jersey, shorts, socks, shin‑guards, boots.
# 5. **The Referee** – authority, signals, and disciplinary powers.
# 6. **Assistant Referees** – flag duties, off‑side monitoring.
# 7. **Duration of the Match** – two 45‑minute halves, added time, extra time, penalties.
# 8. **The Start and Restart of Play** – kick‑offs, throw‑ins, goal kicks, corner kicks, free kicks.
# 9. **The Ball In and Out of Play** – when the ball is considered active.
# 10. **Scoring** – a goal is scored when the whole ball crosses the line between the posts.
# 11. **Off‑side** – attacker must have at least two opponents (including goalkeeper) nearer to his own goal line at the moment the ball is played.
# 12. **Fouls & Misconduct** – direct/indirect free kicks, penalty kicks, caution (yellow), dismissal (red).
# 13. **Free Kicks** – direct vs. indirect, wall placement, distance.
# 14. **The Penalty Kick** – taken from 11 m, only the goalkeeper may move laterally.
# 15. **The Throw‑in** – both feet on ground, ball delivered with both hands from behind the head.
# 16. **The Goal Kick** – taken from within the goal area; ball must leave the penalty area before being touched by another player.
# 17. **The Corner Kick** – awarded when the ball crosses the goal line (not a goal) last touched by a defender.
#
# ### 3.2 The Pitch & Equipment
#
# - **Dimensions:** Length 100‑110 m, width 64‑75 m (international standard: 105 m × 68 m).
# - **Markings:** Half‑way line, centre circle (9.15 m radius), penalty area (16.5 m), goal area (5.5 m), corner arcs.
# - **Goalposts:** 7.32 m wide, 2.44 m high, netted.
# - **Ball:** Hand‑stitched or thermally bonded leather/PU; FIFA‑approved.
# - **Gear:**
#   - **Shin‑guards** – mandatory, must be covered by socks.
#   - **Boots** – stud configuration varies by surface (firm ground, soft ground, artificial turf).
#
# ### 3.3 Player Positions & Roles
#
# | Position | Typical Duties | Key Attributes |
# |----------|----------------|----------------|
# | **Goalkeeper** | Shot‑stopping, distribution, organizing defense | Reflexes, height, composure |
# | **Centre‑Back** | Marking strikers, aerial duels, playing out from the back | Strength, positioning, passing |
# | **Full‑Back** | Defending wide areas, overlapping runs, crossing | Pace, stamina, crossing accuracy |
# | **Defensive Midfielder** | Shielding defence, recycling possession | Tackling, vision, positional discipline |
# | **Box‑to‑Box Midfielder** | Linking defence & attack, covering large ground | Stamina, work‑rate, ball control |
# | **Attacking Midfielder** | Creating chances, linking with forwards | Creativity, dribbling, shooting |
# | **Winger** | Stretching play, delivering crosses, cutting inside | Speed, dribbling, finishing |
# | **Striker** | Scoring, holding up the ball, pressing | Finishing, movement, physicality |
#
# ### 3.4 Match Structure
#
# - **Regulation Time:** Two 45‑minute halves with a 15‑minute halftime.
# - **Stoppage/Added Time:** Referee adds minutes for injuries, substitutions, and time‑wasting.
# - **Extra Time:** Two 15‑minute halves if knockout match ends level.
# - **Penalty Shoot‑out:** Five‑kick series, then sudden death if still tied.
#
# ### 3.5 Refereeing & Technology
#
# | Tech | Function | Current Status |
# |------|----------|----------------|
# | **VAR (Video Assistant Referee)** | Reviews goals, penalties, direct red cards, mistaken identity. | Mandatory in top leagues & FIFA tournaments. |
# | **Goal‑Line Technology (GLT)** | Confirms whether the ball fully crossed the line. | Used in all UEFA and FIFA competitions. |
# | **Semi‑Automated Off‑side (SAO)** | 3‑D sensor‑based system delivering off‑side decisions within seconds. | Pilot in 2024, full rollout expected 2026. |
# | **Wearable Sensors** | Track player load, heart rate, and injury risk. | Integrated into training; limited in‑match use due to privacy concerns. |
# | **AI‑Assisted Refereeing** | Predictive analytics for foul likelihood; still experimental. | Trials in select youth leagues. |
#
# ---
#
# ## 4. Tactical Landscape
#
# ### 4.1 Formations Through the Ages
#
# | Era | Formation | Core Idea | Notable Exponents |
# |-----|-----------|-----------|-------------------|
# | **Late 1800s** | **2‑3‑5 “Pyramid”** | Attack‑heavy; five forwards. | Aston Villa (1888) |
# | **1930s‑40s** | **WM (3‑2‑2‑3)** | Introduced centre‑half as a defender. | Arsenal under Herbert Chapman |
# | **1970s** | **4‑4‑2** | Balanced, two strikers, flat midfield. | Liverpool, England (1974) |
# | **1990s** | **3‑5‑2** | Wing‑backs provide width; strong midfield. | Juventus under Marcello Lippi |
# | **2000s** | **4‑2‑3‑1** | Double pivot, attacking midfield trio. | Spain (Euro 2008, World Cup 2010) |
# | **2010s** | **4‑3‑3 / 4‑1‑4‑1** | High press, inverted wingers. | Pep Guardiola’s Barcelona & Bayern |
# | **2020s** | **3‑4‑3 / False‑9** | Fluid front three, striker drops deep. | Liverpool under Jürgen Klopp (2020‑21) |
# | **Emerging** | **5‑2‑3 (Wing‑Backs)** | Defensive solidity, quick transitions. | Tottenham under Antonio Conte (2022) |
#
# ### 4.2 Core Concepts
#
# - **Possession vs. Counter‑Attack:**
#   - *Possession* (e.g., Barcelona’s “tiki‑taka”) aims to dominate ball control, tire opponents, and create high‑percentage chances.
#   - *Counter‑Attack* (e.g., Leicester City’s 2015‑16 title run) relies on quick transitions after winning the ball, exploiting space behind a high line.
#
# - **Pressing:**
#   - *High Press* – defenders push up to win the ball near the opponent’s goal.
#   - *Mid‑Block* – press in midfield, balancing compactness and space.
#   - *Low Block* – sit deep, absorb pressure, and hit on the break.
#
# - **Marking Systems:**
#   - *Zonal* – players defend areas rather than specific opponents.
#   - *Man‑to‑Man* – each defender tracks a designated attacker.
#
# - **Defensive Lines:**
#   - *High Line* – offside trap, requires pace and coordination.
#   - *Low Line* – reduces space behind, useful against fast forwards.
#
# ### 4.3 Set‑Piece Strategies
#
# | Set‑Piece | Common Variations | Tactical Goal |
# |-----------|-------------------|---------------|
# | **Corner** | Near‑post flick, short corner, crowding the six‑yard box. | Create confusion, increase scoring odds. |
# | **Free‑Kick (Direct)** | Curved “bending” shot, “knuckle
