# %%
from langgraph.graph import StateGraph, START,END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model="openai/gpt-oss-120b")

# %%
class LLMState(TypedDict):
    question:str
    answer:str

# %%
def llm_qa(state: LLMState)->LLMState:
    question = state['question']
    prompt = f'Answer the following Question {question}'
    answer = model.invoke(prompt).content
    state['answer'] = answer
    return state

# %%
graph = StateGraph(LLMState)
graph.add_node('llm_qa',llm_qa)
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)
workflow = graph.compile()

# %%
initial_state = {'question':'Which AI Tech is most in demand?'}
final_state = workflow.invoke(initial_state)

final_state['answer']
# Out:
# '**Short answer:**  \nRight now, **generative AI—especially large‑language‑model (LLM) technologies**—is the most in‑demand AI skill set across industries.\n\n**Why it’s topping the demand list**\n\n| AI Domain | Typical Use‑Cases | Why Companies Want It | Market Signals (2023‑2024) |\n|-----------|-------------------|-----------------------|----------------------------|\n| **Generative AI (LLMs, ChatGPT‑style models, diffusion models for images/video)** | • Customer‑service chatbots<br>• Content creation (text, code, images, video)<br>• Knowledge‑base search & summarization<br>• Personal assistants & copilot tools | • Can be deployed quickly for high‑impact ROI<br>• Reduces labor costs for content‑heavy tasks<br>• Enables new product categories (AI‑assisted design, coding, marketing) | • Venture funding for LLM startups up >\u202f30% YoY (2023‑24)<br>• Enterprise contracts for OpenAI, Anthropic, Cohere, etc., exceed $10\u202fB combined<br>• Job postings for “Prompt Engineer”, “LLM Engineer”, “AI Copilot Developer” up ~150% YoY |\n| **MLOps & AI Ops** | • Model deployment pipelines<br>• Monitoring, scaling, governance | • Companies need to move from prototypes to production at scale | • Tools like MLflow, Kubeflow, Vertex AI seeing 2‑3× growth in enterprise licenses |\n| **Computer Vision (CV)** | • Quality inspection, autonomous navigation, retail analytics | • High‑value in manufacturing, logistics, security | • CV job listings still strong but growing slower than LLM roles |\n| **AI for Healthcare & Bioinformatics** | • Drug discovery, medical imaging, patient triage | • Regulatory approvals drive high‑value contracts | • Niche but high‑pay; demand rising slower than generative AI |\n| **Reinforcement Learning & Robotics** | • Warehouse automation, autonomous drones, game AI | • Specialized, high barrier to entry | • Demand stable, not exploding |\n\n**Key take‑aways for professionals**\n\n1. **Learn to work with LLMs** – get comfortable with prompt engineering, fine‑tuning, and integrating APIs (OpenAI, Anthropic, Cohere, LLaMA‑derived models).\n2. **Pick up a production‑ready stack** – Python + PyTorch/TensorFlow for model work, plus Docker/Kubernetes + CI/CD for MLOps.\n3. **Understand prompt‑to‑product pipelines** – data preprocessing, retrieval‑augmented generation (RAG), safety/guardrails, and evaluation metrics.\n4. **Stay aware of emerging “AI‑Copilot” ecosystems** – Microsoft 365 Copilot, GitHub Copilot, Adobe Firefly, etc., which are creating new developer roles.\n\n**Bottom line:** If you’re aiming for the fastest‑growing, highest‑paying AI niche right now, focus on **generative AI built on large language models** and the surrounding MLOps/AI‑productization skill set.'
